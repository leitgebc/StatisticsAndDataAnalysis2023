# %%
import math
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

def f(x):
    return np.sin(x)**2 - np.cos(x)**3

r = np.random.random(1000000)
sim = r*2*math.pi
u = np.random.random(1000000)
y = -1.0 + u*2.0

neumann = sim[(y<f(sim))]
axisarray = y[(y<f(sim))]
rejected = sim[(y>=f(sim))]
rej_axis = y[(y>f(sim))]

x = np.linspace(0,2*math.pi,neumann.size)


plt.plot(neumann, axisarray, '.', color='blue', markersize=0.01)
plt.plot(rejected, rej_axis, '.', color='green', markersize=0.01)
plt.plot(x, f(x), color='orange')

# %%
plt.hist(neumann, bins=100, color='red', edgecolor='black', histtype='stepfilled', alpha=0.3)
#plt.plot(x, f(x), color='orange')
# Out:
# (array([   35.,   162.,   398.,   690.,  1112.,  1558.,  2100.,  2613.,
#          3361.,  3915.,  4578.,  5179.,  5755.,  6508.,  6989.,  7676.,
#          7983.,  8576.,  9036.,  9274.,  9467.,  9664.,  9942.,  9867.,
#         10139., 10022.,  9765.,  9948.,  9614.,  9818.,  9682.,  9616.,
#          9408.,  9161.,  9035.,  9282.,  9272.,  9175.,  9210.,  9329.,
#          9510.,  9289.,  9589.,  9636.,  9731.,  9811., 10028.,  9777.,
#          9954.,  9918.,  9944., 10065.,  9730.,  9896.,  9678.,  9654.,
#          9660.,  9375.,  9626.,  9390.,  9256.,  9197.,  9193.,  9097.,
#          9295.,  9283.,  9301.,  9397.,  9683.,  9701.,  9519.,  9904.,
#          9882.,  9830., 10099.,  9899.,  9847.,  9734.,  9603.,  9301.,
#          9015.,  8752.,  8691.,  7937.,  7580.,  7048.,  6384.,  5899.,
#          5134.,  4535.,  3705.,  3062.,  2551.,  1962.,  1477.,  1052.,
#           650.,   322.,   119.,    25.]),
#  array([0.01806618, 0.08063673, 0.14320729, 0.20577784, 0.26834839,
#         0.33091895, 0.3934895 , 0.45606005, 0.51863061, 0.58120116,
#         0.64377172, 0.70634227, 0.76891282, 0.83148338, 0.89405393,
#         0.95662448, 1.01919504, 1.08176559, 1.14433615, 1.2069067 ,
#         1.26947725, 1.33204781, 1.39461836, 1.45718891, 1.51975947,
#         1.58233002, 1.64490058, 1.70747113, 1.77004168, 1.83261224,
#         1.89518279, 1.95775334, 2.0203239 , 2.08289445, 2.14546501,
#         2.20803556, 2.27060611, 2.33317667, 2.39574722, 2.45831777,
#         2.52088833, 2.58345888, 2.64602944, 2.70859999, 2.77117054,
#         2.8337411 , 2.89631165, 2.9588822 , 3.02145276, 3.08402331,
#         3.14659387, 3.20916442, 3.27173497, 3.33430553, 3.39687608,
#         3.45944663, 3.52201719, 3.58458774, 3.6471583 , 3.70972885,
#         3.7722994 , 3.83486996, 3.89744051, 3.96001106, 4.02258162,
#         4.08515217, 4.14772273, 4.21029328, 4.27286383, 4.33543439,
#         4.39800494, 4.46057549, 4.52314605, 4.5857166 , 4.64828716,
#         4.71085771, 4.77342826, 4.83599882, 4.89856937, 4.96113992,
#         5.02371048, 5.08628103, 5.14885159, 5.21142214, 5.27399269,
#         5.33656325, 5.3991338 , 5.46170435, 5.52427491, 5.58684546,
#         5.64941602, 5.71198657, 5.77455712, 5.83712768, 5.89969823,
#         5.96226878, 6.02483934, 6.08740989, 6.14998045, 6.212551  ,
#         6.27512155]),
#  [<matplotlib.patches.Polygon at 0x7fa291247910>])
